# %% [markdown]
# <hr style="border:5px solid #108999"> </hr>

# %% [markdown]
# Location,Region data set

# %% [markdown]
# # pandas Series <hr style="border:4.5px solid #108999"> </hr>

# %% [markdown]
# For starters, import the pandas library, using the relevant well-known convention.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## .unique() & .nunique()

# %% [markdown]
# Load the "Region.csv" file and use the *squeeze* function and set it to *True*. Store the information in a variable called **region_data**. Preview the data with the pandas *.head()* method.

# %%
x=pd.read_csv('/content/Region.csv')
x.head()
# Out:
#      Region
# 0  Region 2
# 1  Region 6
# 2  Region 3
# 3  Region 2
# 4  Region 3

# %% [markdown]
# Verify that **region_data** is a Series object.

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **Use** the *.describe()* method to obtain descriptive statistics on the **region_data** Series.
# <br>Think of how many unique values there are in the data set.
# <br>*Please note that the statistics provided in the output exclude missing data.*

# %%
x.describe()
# Out:
#           Region
# count       1042
# unique        18
# top     Region 6
# freq         326

# %% [markdown]
# You can obtain some of the values from the previous output by using Python built-in functions or methods. Please extract the total number of values from the **region_data** Series, then the number of unique values. Finally, obtain a list containing all unique values from this Series.

# %%
x['Region'].nunique()
#x['Region'].unique()
# Out:
# 18

# %%
x['Region'].unique()
# Out:
# array(['Region 2', 'Region 6', 'Region 3', 'Region 1', 'Region 5',
#        'Region 9', 'Region 7', 'Region 4', 'Region 12', 'Region 16',
#        'Region 8', 'Region 10', 'Region 13', 'Region 15', 'Region 11',
#        'Region 14', 'Region 17', 'Region 18'], dtype=object)

# %% [markdown]
# ## .sort_values()

# %% [markdown]
# Load the "Region.csv" file and use the *squeeze* function and set it to *True*.. Store the information in a variable called **region_data**. Preview the data with the pandas *.head()* method.

# %%
x.sort_values(by='Region')
# Out:
#        Region
# 462  Region 1
# 347  Region 1
# 609  Region 1
# 610  Region 1
# 339  Region 1
# ..        ...
# 536  Region 9
# 450  Region 9
# 8    Region 9
# 842  Region 9
# 940  Region 9
#
# [1042 rows x 1 columns]

# %% [markdown]
# Sort the values without specifying any arguments.

# %% [markdown]
# *Please note that the numbers go from 1 to 18, but we are currently ordering the values as labels, not integers. 1 is succeeded by 10, then 11, and so on until 18. Then we have 2, 3, 4, etc., until 8, and eventually - 9.*

# %%
region_data = x.squeeze()
region_data.sort_values()
# Out:
# 462    Region 1
# 347    Region 1
# 609    Region 1
# 610    Region 1
# 339    Region 1
#          ...
# 536    Region 9
# 450    Region 9
# 8      Region 9
# 842    Region 9
# 940    Region 9
# Name: Region, Length: 1042, dtype: object

# %% [markdown]
# Sort the values, setting the *ascending* parameter equal to *True*.

# %%
x.sort_values(by='Region',ascending=True)
# Out:
#        Region
# 462  Region 1
# 347  Region 1
# 609  Region 1
# 610  Region 1
# 339  Region 1
# ..        ...
# 536  Region 9
# 450  Region 9
# 8    Region 9
# 842  Region 9
# 940  Region 9
#
# [1042 rows x 1 columns]

# %% [markdown]
# Sort the values in **region_data** in descending order.

# %%
x.sort_values(by='Region',ascending=False)
# Out:
#        Region
# 450  Region 9
# 842  Region 9
# 141  Region 9
# 940  Region 9
# 8    Region 9
# ..        ...
# 569  Region 1
# 892  Region 1
# 558  Region 1
# 557  Region 1
# 309  Region 1
#
# [1042 rows x 1 columns]

# %% [markdown]
# ## Attribute and Method Chaining

# %% [markdown]
# Load the "Region.csv" file and use the *squeeze* function and set it to *True*. Store the information in a variable called **region_data**. Preview the data with the pandas *.head()* method.

# %%
region_data = pd.read_csv("Region.csv").squeeze()
region_data.head()
# Out:
# 0    Region 2
# 1    Region 6
# 2    Region 3
# 3    Region 2
# 4    Region 3
# Name: Region, dtype: object

# %% [markdown]
# Get the shape of the region_data DataFrame

# %%
region_data.shape
# Out:
# (1042,)

# %% [markdown]
# Get information about region_data

# %%
region_data.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1042 entries, 0 to 1041
# Series name: Region
# Non-Null Count  Dtype
# --------------  -----
# 1042 non-null   object
# dtypes: object(1)
# memory usage: 8.3+ KB

# %% [markdown]
# Check total number of duplicates

# %%
region_data.duplicated().sum()
# Out:
# np.int64(1024)

# %% [markdown]
# Remove duplicate rows

# %%
region_data.drop_duplicates()
# Out:
# 0       Region 2
# 1       Region 6
# 2       Region 3
# 5       Region 1
# 6       Region 5
# 8       Region 9
# 13      Region 7
# 20      Region 4
# 21     Region 12
# 71     Region 16
# 148     Region 8
# 161    Region 10
# 181    Region 13
# 217    Region 15
# 263    Region 11
# 370    Region 14
# 555    Region 17
# 623    Region 18
# Name: Region, dtype: object

# %% [markdown]
# Check if there are any duplicate rows after removing them

# %%
region_data.duplicated().sum()
# Out:
# np.int64(1024)

# %% [markdown]
# Execute the next code cell to create a Series object called **emp_birth_date** that contains the employee numbers and the dates of birth of certain 4 employees.

# %%
emp_birth_date=pd.Series(["1990-05-12", "1988-03-22", "1995-11-30", "1992-07-18"],index=[1001, 1002, 1003, 1004])
emp_birth_date
# Out:
# 1001    1990-05-12
# 1002    1988-03-22
# 1003    1995-11-30
# 1004    1992-07-18
# dtype: object

# %% [markdown]
# Obtain just the index of **emp_birth_date**.

# %%
emp_birth_date.index
# Out:
# Index([1001, 1002, 1003, 1004], dtype='int64')

# %% [markdown]
# Obtain the row labels of the index, i.e. its values, stored in an array.

# %%
emp_birth_date.index.values
# Out:
# array([1001, 1002, 1003, 1004])
