# %%
# prerequisite package imports
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
df=pd.read_csv('/content/pokemon.csv')

# %%
df.head()
# Out:
#    id     species  generation_id  height  weight  base_experience type_1  \
# 0   1   bulbasaur              1     0.7     6.9               64  grass
# 1   2     ivysaur              1     1.0    13.0              142  grass
# 2   3    venusaur              1     2.0   100.0              236  grass
# 3   4  charmander              1     0.6     8.5               62   fire
# 4   5  charmeleon              1     1.1    19.0              142   fire
#
#    type_2  hp  attack  defense  speed  special-attack  special-defense
# 0  poison  45      49       49     45              65               65
# 1  poison  60      62       63     60              80               80
# 2  poison  80      82       83     80             100              100
# 3     NaN  39      52       43     65              60               50
# 4     NaN  58      64       58     80              80               65

# %% [markdown]
# In this workspace, you'll perform some polishing and cleanup of a plot created using the Pokémon creature dataset.

# %% [markdown]
# **Task**: Perform polishing and cleaning steps for the following multivariate plot, where the relationship between height and weight are depicted for the Fairy and Dragon Pokémon types. You'll need to do more than just add meaningful labels and titles to the plot. Pay attention to the interpretability of tick marks and the ability to associate each point to a type of Pokemon.
#
# For reference, height is in terms of meters and weight is in terms of kilograms. One other thing you might try is to change the colors mapped to each type to match those given by the game series. Fairy is depicted with a light pink (hex code #ee99ac) while Dragon is associated with a medium purple (hex code #7038f8). (Type colors taken from [Pokémon Wiki Bulbapedia](https://bulbapedia.bulbagarden.net/wiki/Category:Type_color_templates).)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

subset = df[df['type_1'].isin(['fairy', 'dragon'])]
type_colors = {
    'fairy': '#ee99ac',   # Light Pink
    'dragon': '#7038f8'   # Medium Purple
}
plt.figure(figsize=(10,6))

sns.scatterplot(
    data=subset,
    x='height',
    y='weight',
    hue='type_1',
    palette=type_colors,
    s=80,
    edgecolor='black'
)

plt.title("Height vs Weight for Fairy and Dragon Pokémon", fontsize=14, weight='bold')
plt.xlabel("Height (meters)", fontsize=12)
plt.ylabel("Weight (kg)", fontsize=12)

plt.xticks(rotation=0)
plt.grid(True, linestyle='--', alpha=0.5)

plt.legend(title="Pokémon Type")
plt.tight_layout()
plt.show()

# %%
df['type_1'].unique()
# Out:
# array(['grass', 'fire', 'water', 'bug', 'normal', 'poison', 'electric',
#        'ground', 'fairy', 'fighting', 'psychic', 'rock', 'ghost', 'ice',
#        'dragon', 'dark', 'steel', 'flying'], dtype=object)

# %%
df = pd.read_csv('/content/pokemon.csv')

# اختيار Fairy و Dragon فقط
subset = df[df['type_1'].isin(['fairy', 'dragon'])]

# ألوان مطابقة للعبة
type_colors = {
    'fairy': '#ee99ac',   # Light Pink
    'dragon': '#7038f8'   # Medium Purple
}

plt.figure(figsize=(10,6))

sns.scatterplot(
    data=subset,
    x='height',
    y='weight',
    hue='type_1',
    palette=type_colors,
    s=100,
    edgecolor='black'
)

plt.title("Height vs Weight of Fairy and Dragon Pokémon", fontsize=14, weight='bold')
plt.xlabel("Height (meters)", fontsize=12)
plt.ylabel("Weight (kg)", fontsize=12)

plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(title="Pokémon Type")
plt.tight_layout()
plt.show()

# %%
df[df['type_1'].isin(['fairy', 'dragon'])][
    ['species', 'type_1', 'height', 'weight']
]
# Out:
#         species  type_1  height  weight
# 34     clefairy   fairy     0.6     7.5
# 35     clefable   fairy     1.3    40.0
# 146     dratini  dragon     1.8     3.3
# 147   dragonair  dragon     4.0    16.5
# 148   dragonite  dragon     2.2   210.0
# 172      cleffa   fairy     0.3     3.0
# 174      togepi   fairy     0.3     1.5
# 175     togetic   fairy     0.6     3.2
# 208    snubbull   fairy     0.6     7.8
# 209    granbull   fairy     1.4    48.7
# 333     altaria  dragon     1.1    20.6
# 370       bagon  dragon     0.6    42.1
# 371     shelgon  dragon     1.1   110.5
# 372   salamence  dragon     1.5   102.6
# 379      latias  dragon     1.4    40.0
# 380      latios  dragon     2.0    60.0
# 383    rayquaza  dragon     7.0   206.5
# 442       gible  dragon     0.7    20.5
# 443      gabite  dragon     1.4    56.0
# 444    garchomp  dragon     1.9    95.0
# 467    togekiss   fairy     1.5    38.0
# 609        axew  dragon     0.6    18.0
# ...

# %%
df1 = df[df['type_1'].isin(['fairy', 'dragon'])]
type_colors = {
    'fairy': '#ee99ac',
    'dragon': '#7038f8'
}
plt.figure(figsize=(12,6))
sns.scatterplot(
    data=subset,
    x='weight',
    y='height',
    hue='type_1',
    palette=type_colors,
    s=80
)
plt.xscale('log')

plt.title("Height vs. Weight for Fairy and Dragon Pokémon", fontsize=14)
plt.xlabel("Weight (kg, log scale)")
plt.ylabel("Height (m)")

plt.legend(title="Pokémon Type")
plt.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()
